# %% [markdown]
# ### Install Nlpcloud module

# %%
! pip install nlpcloud
# Out:
# Collecting nlpcloud
#   Downloading nlpcloud-1.1.47-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from nlpcloud) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->nlpcloud) (2025.11.12)
# Downloading nlpcloud-1.1.47-py3-none-any.whl (3.9 kB)
# Installing collected packages: nlpcloud
# Successfully installed nlpcloud-1.1.47

# %% [markdown]
# # SmartText **AI**

# %%
import nlpcloud

class NLPApp:
    def __init__(self):
        self.__database = {}
        self.__first_menu()

    def __first_menu(self):
        while True:
            first_input = input("""

            Hi! How would you like to proceed?

            1. Not a member? Register
            2. Already Member? Login
            3. Exit

            Enter your choice: """)

            if first_input == "1":
                self.__register()
                break

            elif first_input == "2":
                self.__login()
                break

            elif first_input == "3":
                print("Exiting... Goodbye!")
                exit()

            else:
                print("Invalid Input! Enter 1/2/3")

    def __register(self):
        username = input("Create Username: ")
        password = input("Create Password: ")

        if username in self.__database:
            print("User already exists! Try Login.")
            self.__first_menu()
        else:
            self.__database[username] = password
            print("Registration successful! Login now\n")
            self.__first_menu()

    def __login(self):
        username = input("Enter Username: ")
        password = input("Enter Password: ")

        if username in self.__database and self.__database[username] == password:
            print("Login Successful!\n")
            self.__second_menu()
        else:
            print("Invalid Username or Password!\n")
            self.__first_menu()

    def __second_menu(self):
        while True:
            user_input = input("""

            What would you like to do?

            1. Named Entity Recognition (NER)
            2. Language Detection
            3. Sentiment Analysis
            4. Chatbot
            5. Intent Classification
            6. Grammar & Spelling Correction
            7. Logout

            Enter your choice: """)

            if user_input == "1":
                self.__ner()

            elif user_input == "2":
                self.__language()

            elif user_input == "3":
                self.__sentiment()

            elif user_input == "4":
                self.__chatbot()

            elif user_input == "5":
                self.__intent_classification()

            elif user_input == "6":
                self.__gs_correction()

            elif user_input == "7":
                print("Logged out successfully!\n")
                self.__first_menu()
                break

            else:
                print("Invalid Input! Enter correct option.")



    def __ner(self):
        print("\n---- Named Entity Recognition ----")
        text = input("Enter text: ")
        entity_type = input("Enter entity type (example: persons, locations, organizations): ")

        client = nlpcloud.Client("gpt-oss-120b",
                                 "58f6044277258c8f6f20ba9445880e2406cad41f",
                                 gpu=True)

        response = client.entities(text, searched_entity=entity_type)
        print("\nNER Result:", response)

    def __language(self):
        print("\n---- Language Detection ----")
        text = input("Enter text: ")

        client = nlpcloud.Client("python-langdetect",
                                 "58f6044277258c8f6f20ba9445880e2406cad41f",
                                 gpu=False)

        response = client.langdetection(text)
        print("\nDetected Language:", response)

    def __sentiment(self):
        print("\n---- Sentiment Analysis ----")
        text = input("Enter text: ")

        client = nlpcloud.Client("gpt-oss-120b",
                                 "58f6044277258c8f6f20ba9445880e2406cad41f",
                                 gpu=True)

        response = client.sentiment(text)
        print("\nSentiment Result:", response)

    def __chatbot(self):
        print("\n---- ChatBot (type 'exit' to stop) ----")

        client = nlpcloud.Client("gpt-oss-120b",
                                 "58f6044277258c8f6f20ba9445880e2406cad41f",
                                 gpu=True)
        history = []

        while True:
            msg = input("You: ")
            if msg.lower() == "exit":
                print("Chat Ended!")
                break

            res = client.chatbot(msg, history=history)
            reply = res["response"]
            print("AI:", reply)
            history.append({"input": msg, "response": reply})

    def __intent_classification(self):
        print("\n---- Intent Classification ----")
        text = input("Enter text: ")

        client = nlpcloud.Client("gpt-oss-120b",
                                 "58f6044277258c8f6f20ba9445880e2406cad41f",
                                 gpu=True)

        response = client.intent_classification(text)
        print("\nIntent Detected:", response)

    def __gs_correction(self):
        print("\n---- Grammar & Spelling Correction ----")
        text = input("Enter text to correct: ")

        client = nlpcloud.Client("gpt-oss-120b",
                                 "58f6044277258c8f6f20ba9445880e2406cad41f",
                                 gpu=True)

        response = client.gs_correction(text)
        print("\nCorrected Sentence:", response)


# -------- Start Application ----------
app = NLPApp()
# Out:
#             Hi! How would you like to proceed?
#
#             1. Not a member? Register
#             2. Already Member? Login
#             3. Exit
#
#             Enter your choice: 1
# Create Username: rahul
# Create Password: rahul123
# Registration successful! Login now
#
#
#
#             Hi! How would you like to proceed?
#
#             1. Not a member? Register
#             2. Already Member? Login
#             3. Exit
#
#             Enter your choice: 2
# Enter Username: rahul
# Enter Password: rahul123
# Login Successful!
#
#
#
#             What would you like to do?
#
#             1. Named Entity Recognition (NER)
#             2. Language Detection
#             3. Sentiment Analysis
#             4. Chatbot
#             5. Intent Classification
#             6. Grammar & Spelling Correction
#             7. Logout
#
#             Enter your choice: 1
#
# ---- Named Entity Recognition ----
# Enter text: Barack Obama lives in Washington
# Enter entity type (example: persons, locations, organizations): persons
#
# NER Result: {'entities': [{'start': 0, 'end': 12, 'type': 'persons', 'text': 'Barack Obama'}]}
#
#
#             What would you like to do?
#
#             1. Named Entity Recognition (NER)
#             2. Language Detection
#             3. Sentiment Analysis
#             4. Chatbot
#             5. Intent Classification
#             6. Grammar & Spelling Correction
#             7. Logout
#
#             Enter your choice: 2
#
# ---- Language Detection ----
# Enter text: hi i am rahul
#
# Detected Language: {'languages': [{'id': 0.7142836974620845}, {'cy': 0.14285783812325312}, {'sw': 0.14285656707017627}]}
#
#
#             What would you like to do?
#
#             1. Named Entity Recognition (NER)
#             2. Language Detection
#             3. Sentiment Analysis
#             4. Chatbot
#             5. Intent Classification
#             6. Grammar & Spelling Correction
#             7. Logout
#
#             Enter your choice: 3
#
# ---- Sentiment Analysis ----
# Enter text: I hate this.
#
# Sentiment Result: {'scored_labels': [{'label': 'NEGATIVE', 'score': 1}, {'label': 'hate', 'score': 1}]}
#
#
#             What would you like to do?
#
#             1. Named Entity Recognition (NER)
#             2. Language Detection
#             3. Sentiment Analysis
#             4. Chatbot
#             5. Intent Classification
#             6. Grammar & Spelling Correction
#             7. Logout
#
#             Enter your choice: 4
#
# ---- ChatBot (type 'exit' to stop) ----
# You: Hello
# AI: Hello! How can I assist you today?
# You: exit
# Chat Ended!
#
#
#             What would you like to do?
#
#             1. Named Entity Recognition (NER)
#             2. Language Detection
#             3. Sentiment Analysis
#             4. Chatbot
#             5. Intent Classification
#             6. Grammar & Spelling Correction
#             7. Logout
#
#             Enter your choice: 5
#
# ---- Intent Classification ----
# Enter text: I want a refund
#
# Intent Detected: {'intent': 'Request refund'}
#
#
#             What would you like to do?
#
#             1. Named Entity Recognition (NER)
#             2. Language Detection
#             3. Sentiment Analysis
#             4. Chatbot
#             5. Intent Classification
#             6. Grammar & Spelling Correction
#             7. Logout
#
#             Enter your choice: 6
#
# ---- Grammar & Spelling Correction ----
# Enter text to correct: He go to school yesterday
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/nlpcloud/__init__.py in gs_correction(self, text)
#     236         try:
# --> 237             r.raise_for_status()
#     238         except HTTPError as err:
#
# /usr/local/lib/python3.12/dist-packages/requests/models.py in raise_for_status(self)
#    1025         if http_error_msg:
# -> 1026             raise HTTPError(http_error_msg, response=self)
#    1027
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/gpt-oss-120b/gs-correction
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-2920927970.py in <cell line: 0>()
#     177
#     178 # -------- Start Application ----------
# --> 179 app = NLPApp()
#
# /tmp/ipython-input-2920927970.py in __init__(self)
#       4     def __init__(self):
#       5         self.__database = {}
# ----> 6         self.__first_menu()
#       7
#       8     def __first_menu(self):
#
# /tmp/ipython-input-2920927970.py in __first_menu(self)
#      19
#      20             if first_input == "1":
# ---> 21                 self.__register()
#      22                 break
#      23
#
# /tmp/ipython-input-2920927970.py in __register(self)
#      43             self.__database[username] = password
#      44             print("Registration successful! Login now\n")
# ---> 45             self.__first_menu()
#      46
#      47     def __login(self):
#
# /tmp/ipython-input-2920927970.py in __first_menu(self)
#      23
#      24             elif first_input == "2":
# ---> 25                 self.__login()
#      26                 break
#      27
#
# /tmp/ipython-input-2920927970.py in __login(self)
#      51         if username in self.__database and self.__database[username] == password:
#      52             print("Login Successful!\n")
# ---> 53             self.__second_menu()
#      54         else:
#      55             print("Invalid Username or Password!\n")
#
# /tmp/ipython-input-2920927970.py in __second_menu(self)
#      88
#      89             elif user_input == "6":
# ---> 90                 self.__gs_correction()
#      91
#      92             elif user_input == "7":
#
# /tmp/ipython-input-2920927970.py in __gs_correction(self)
#     172                                  gpu=True)
#     173
# --> 174         response = client.gs_correction(text)
#     175         print("\nCorrected Sentence:", response)
#     176
#
# /usr/local/lib/python3.12/dist-packages/nlpcloud/__init__.py in gs_correction(self, text)
#     237             r.raise_for_status()
#     238         except HTTPError as err:
# --> 239             raise HTTPError(str(err) + ": " + str(r.text))
#     240
#     241         return r.json()
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.nlpcloud.io/v1/gpu/gpt-oss-120b/gs-correction: Rate limit: maximum number of requests per hour reached. Please contact support to learn how to increase this limit (if you are on the free plan, we encourage you to subscribe to the pay-as-you-go plan which provides a much higher throughput and many free requests). You can change your plan here: https://nlpcloud.com/home/plans.
